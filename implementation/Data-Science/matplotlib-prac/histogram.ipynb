# %%
import matplotlib.pyplot as plt
import numpy as np

d = np.random.laplace(loc=15, scale=3, size=500)
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=d, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 80.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

d = np.random.randint(low=1, high=11, size=100)
print(np.concatenate((d, [3,3,3,3,3,3,3,3,3,3,3,3,3])))
n, bins, patches = plt.hist(x=d, bins=10, color='#0504aa', alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlim([1,10])
# plt.ylim([0.0,1.0])
# Out:
# [ 9  9  5  3  8  6  9  7  5  2  2  5  6  4  8  1  5  5  4  2  6  4  9  8
#   2  5  1  4  5  3  1  1  3  3  3  8  1 10  6  8  5  5  8 10  5  4  6 10
#   3  8  2  4  7  6  9  3  5  1  8  8  4  5  6  7  1  4  6  7  8  1  3  5
#   5  2  5  9  2  5  6 10  7  6  9  6  4  8  1  2  3  9  5  2  8  7  6  9
#   5  5  7  4  3  3  3  3  3  3  3  3  3  3  3  3  3]
# (1.0, 10.0)
